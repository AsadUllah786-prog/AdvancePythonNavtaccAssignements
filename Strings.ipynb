# %%
print("hello world")
# Out:
# hello world

# %%
str1="Asad"
print(len(str1))
print("A" in str1)
print(str1[0])
for a in str1:
    print(a)
if "e" not in str1:
    print("e is not present")
else:
    print("e is present")
# Out:
# 4
# True
# A
# A
# s
# a
# d
# e is not present

# %%
b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %%
print(b.upper())
# Out:
# HELLO, WORLD!

# %%
print(b.lower())
# Out:
# hello, world!

# %%
print(b.strip())
# Out:
# Hello, World!

# %%
print(b.capitalize())
# Out:
# Hello, world!

# %%
a = " Hello, World! "
print(a)
# Out:
#  Hello, World!

# %%
x=(a.strip())

# %%
print(x.replace("H","Y"))
# Out:
# Yello, World!

# %%
print(x.split(","))
# Out:
# ['Hello', ' World!']

# %%
z="a,s,y,z"

# %%
print(z.split(","))
# Out:
# ['a', 's', 'y', 'z']

# %%
a = "Hello"
b = "World"
c = a+b
print(c)
# Out:
# HelloWorld

# %%
age = 36
txt = "My name is Asad, I am " + str(age+4)
print(txt)

print(age)
# Out:
# My name is Asad, I am 40
# 36

# %%
age = 20
txt = f"My name is Asad, I am {age:.1f}"
print(txt)
# Out:
# My name is Asad, I am 20.0

# %%
def asad():
    print("asad is a good boy")

# %%
asad()
# Out:
# asad is a good boy

# %%
person=f" {asad()}"
# Out:
# asad is a good boy

# %%
txt = "We are the\f so-called \"Vikings\" from the north."

# %%
print(txt.lower())
# Out:
# we are the so-called "vikings" from the north.
