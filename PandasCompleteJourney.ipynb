# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df=pd.read_csv(r"C:\Users\User\Downloads\music_recommendations (1).csv")

# %%
df.head()
# Out:
#              track_name       artist_name    genre  similarity_score  \
# 0                lately      moneybagg yo  hip hop          0.316829
# 1  since i fell for you  dinah washington    blues          0.284011
# 2                slowly       webb pierce  country          0.257575
# 3                regret         new order      pop          0.247513
# 4           from now on        supertramp     rock          0.241575
#
#   similarity_percent
# 0              31.7%
# 1              28.4%
# 2              25.8%
# 3              24.8%
# 4              24.2%

# %%
df.shape
# Out:
# (10, 5)

# %%
df.shape #for understanding a shape of our dataset//
# Out:
# (10, 5)

# %%
df.head()
# Out:
#              track_name       artist_name    genre  similarity_score  \
# 0                lately      moneybagg yo  hip hop          0.316829
# 1  since i fell for you  dinah washington    blues          0.284011
# 2                slowly       webb pierce  country          0.257575
# 3                regret         new order      pop          0.247513
# 4           from now on        supertramp     rock          0.241575
#
#   similarity_percent
# 0              31.7%
# 1              28.4%
# 2              25.8%
# 3              24.8%
# 4              24.2%

# %%
df.tail()  # to see the bottom 5 rows
# Out:
#                  track_name  artist_name  genre  similarity_score  \
# 5                 on and on    the score   rock          0.241313
# 6              scholarships        drake    pop          0.241174
# 7    right place wrong time     dr. john  blues          0.235687
# 8  something got me started   simply red    pop          0.232403
# 9                      stay  david bowie   rock          0.229558
#
#   similarity_percent
# 5              24.1%
# 6              24.1%
# 7              23.6%
# 8              23.2%
# 9              23.0%

# %%
df.columns # all columns in dataset
# Out:
# Index(['track_name', 'artist_name', 'genre', 'similarity_score',
#        'similarity_percent'],
#       dtype='object')

# %%
df.dtypes
# Out:
# track_name             object
# artist_name            object
# genre                  object
# similarity_score      float64
# similarity_percent     object
# dtype: object

# %%
df.describe() # statistics information
# Out:
#        similarity_score
# count         10.000000
# mean           0.252764
# std            0.027420
# min            0.229558
# 25%            0.237059
# 50%            0.241444
# 75%            0.255060
# max            0.316829

# %%
# step 1: import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("ggplot")
import random as rd
import math as mt
# step 2: data exploaration
pd.read_csv("path")
pd.head()
pd.tail()
pd.shape
pd.columns
pd.describe()
pd.info()
pd.dtypes
# step 3:data manipulation

# %%
df=df.columns

# %%
df[['track_name', 'artist_name', 'genre', 'similarity_score',
       'similarity_percent']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df[['track_name', 'artist_name', 'genre', 'similarity_score',
#       2        'similarity_percent']]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:5428, in Index.__getitem__(self, key)
#    5419         if len(key) == 0 and len(key) != len(self):
#    5420             warnings.warn(
#    5421                 "Using a boolean indexer with length 0 on an Index with "
#    5422                 "length greater than 0 is deprecated and will raise in a "
#    (...)   5425                 stacklevel=find_stack_level(),
#    5426             )
# -> 5428 result = getitem(key)
#    5429 # Because we ruled out integer above, we always get an arraylike here
#    5430 if result.ndim > 1:
#
# ...

# %%
df.drop(["columns name"],axis=1)
# this is used for dropping columns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.drop(["columns name"],axis=1)
#       2 # this is used for dropping columns
#
# TypeError: Index.drop() got an unexpected keyword argument 'axis'

# %%
df.shape
# Out:
# (5,)

# %%
df=pd.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df=pd.describe()
#
# AttributeError: module 'pandas' has no attribute 'describe'

# %%
pd.to_numeric("convert into numeric")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/lib.pyx:2407, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "convert into numeric"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pd.to_numeric("convert into numeric")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\tools\numeric.py:235, in to_numeric(arg, errors, downcast, dtype_backend)
#     233 coerce_numeric = errors not in ("ignore", "raise")
#     234 try:
# --> 235     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     236         values,
#     237         set(),
#     238         coerce_numeric=coerce_numeric,
# ...

# %%
df.rename("renaming the columns")
# Out:
# Index(['track_name', 'artist_name', 'genre', 'similarity_score',
#        'similarity_percent'],
#       dtype='object', name='renaming the columns')

# %%
df.rename(columns={"oldName":"NewName"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.rename(columns={"oldName":"NewName"})
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# TypeError: Index.rename() got an unexpected keyword argument 'columns'

# %%
df.isna().sum() #to find missing valiues
# Out:
# np.int64(0)

# %%
data=pd.read_csv(r"C:\Users\User\OneDrive\Documents\accounting_data.csv")

# %%
data.head()
# Out:
#    Transaction ID        Date Account Type  Transaction Amount  Cash Flow  \
# 0               1  2025-01-01        Asset                1176       3184
# 1               2  2025-01-02        Asset                1291       3221
# 2               3  2025-01-03      Revenue                4966       3309
# 3               4  2025-01-04      Expense                4641       1952
# 4               5  2025-01-05      Expense                2305       2131
#
#    Net Income  Revenue  Expenditure  Profit Margin  Debt-to-Equity Ratio  \
# 0        2174     3137         1823       0.607221              2.067004
# 1        3236     4694         2746       0.355608              2.347537
# 2        3689     3363         3102       0.678347              1.901003
# 3         245     4373          808       0.221047              0.934125
# 4        2037     4956          644       0.509323              1.061178
#
#    Operating Expenses  Gross Profit  Transaction Volume  \
# ...

# %%
data.shape
# Out:
# (1000, 18)

# %%
data.columns
# Out:
# Index(['Transaction ID', 'Date', 'Account Type', 'Transaction Amount',
#        'Cash Flow', 'Net Income', 'Revenue', 'Expenditure', 'Profit Margin',
#        'Debt-to-Equity Ratio', 'Operating Expenses', 'Gross Profit',
#        'Transaction Volume', 'Processing Time (seconds)', 'Accuracy Score',
#        'Missing Data Indicator', 'Normalized Transaction Amount',
#        'Transaction Outcome'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Transaction ID                 1000 non-null   int64
#  1   Date                           1000 non-null   object
#  2   Account Type                   1000 non-null   object
#  3   Transaction Amount             1000 non-null   int64
#  4   Cash Flow                      1000 non-null   int64
#  5   Net Income                     1000 non-null   int64
#  6   Revenue                        1000 non-null   int64
#  7   Expenditure                    1000 non-null   int64
#  8   Profit Margin                  1000 non-null   float64
#  9   Debt-to-Equity Ratio           1000 non-null   float64
#  10  Operating Expenses             1000 non-null   int64
#  11  Gross Profit                   1000 non-null   int64
# ...

# %%
data.describe()
# Out:
#        Transaction ID  Transaction Amount    Cash Flow   Net Income  \
# count     1000.000000         1000.000000  1000.000000  1000.000000
# mean       500.500000         2535.701000  2426.331000  2114.759000
# std        288.819436         1432.052409  1169.845927  1100.614577
# min          1.000000          106.000000   502.000000   203.000000
# 25%        250.750000         1363.500000  1360.750000  1168.750000
# 50%        500.500000         2498.000000  2452.000000  2075.500000
# 75%        750.250000         3774.000000  3414.000000  3078.500000
# max       1000.000000         4998.000000  4496.000000  3995.000000
#
#            Revenue  Expenditure  Profit Margin  Debt-to-Equity Ratio  \
# count  1000.000000  1000.000000    1000.000000           1000.000000
# mean   2610.989000  2026.188000       0.499085              1.781955
# std    1358.787787  1129.047997       0.171064              0.720989
# min     303.000000   100.000000       0.201363              0.500605
# ...

# %%
data['Transaction ID'].nunique()
# Out:
# 1000

# %%
data['Transaction ID'].value_counts()
# Out:
# Transaction ID
# 1000    1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 13      1
# 12      1
# 11      1
# 10      1
# 9       1
# Name: count, Length: 1000, dtype: int64

# %%
data.nunique()
# Out:
# Transaction ID                   1000
# Date                             1000
# Account Type                        4
# Transaction Amount                910
# Cash Flow                         893
# Net Income                        883
# Revenue                           907
# Expenditure                       866
# Profit Margin                    1000
# Debt-to-Equity Ratio             1000
# Operating Expenses                914
# Gross Profit                      897
# Transaction Volume                  9
# Processing Time (seconds)        1000
# Accuracy Score                   1000
# Missing Data Indicator              2
# Normalized Transaction Amount     910
# Transaction Outcome                 2
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Transaction ID                   0
# Date                             0
# Account Type                     0
# Transaction Amount               0
# Cash Flow                        0
# Net Income                       0
# Revenue                          0
# Expenditure                      0
# Profit Margin                    0
# Debt-to-Equity Ratio             0
# Operating Expenses               0
# Gross Profit                     0
# Transaction Volume               0
# Processing Time (seconds)        0
# Accuracy Score                   0
# Missing Data Indicator           0
# Normalized Transaction Amount    0
# Transaction Outcome              0
# dtype: int64

# %%
data.dropna().sum()
# Out:
# Transaction ID                                                              500500
# Date                             2025-01-012025-01-022025-01-032025-01-042025-0...
# Account Type                     AssetAssetRevenueExpenseExpenseRevenueRevenueA...
# Transaction Amount                                                         2535701
# Cash Flow                                                                  2426331
# Net Income                                                                 2114759
# Revenue                                                                    2610989
# Expenditure                                                                2026188
# Profit Margin                                                           499.085211
# Debt-to-Equity Ratio                                                   1781.955297
# Operating Expenses                                                         2517951
# ...

# %%
data.fillna(0)
# Out:
#      Transaction ID        Date Account Type  Transaction Amount  Cash Flow  \
# 0                 1  2025-01-01        Asset                1176       3184
# 1                 2  2025-01-02        Asset                1291       3221
# 2                 3  2025-01-03      Revenue                4966       3309
# 3                 4  2025-01-04      Expense                4641       1952
# 4                 5  2025-01-05      Expense                2305       2131
# ..              ...         ...          ...                 ...        ...
# 995             996  2027-09-23        Asset                2625       2655
# 996             997  2027-09-24        Asset                 676       1586
# 997             998  2027-09-25      Revenue                2758       3624
# 998             999  2027-09-26    Liability                 796       2063
# 999            1000  2027-09-27      Expense                3387       4041
#
# ...

# %%
data.fillna().mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 data.fillna().mean()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:7312, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7305         if ctr <= ref_count:
#    7306             warnings.warn(
#    7307                 _chained_assignment_warning_method_msg,
#    7308                 FutureWarning,
#    7309                 stacklevel=2,
#    7310             )
# -> 7312 value, method = validate_fillna_kwargs(value, method)
#    7313 if method is not None:
#    7314     warnings.warn(
#    7315         f"{type(self).__name__}.fillna with 'method' is deprecated and "
#    7316         "will raise in a future version. Use obj.ffill() or obj.bfill() "
#    (...)   7319         stacklevel=find_stack_level(),
#    7320     )
#
# ...

# %%
data.columns
# Out:
# Index(['Transaction ID', 'Date', 'Account Type', 'Transaction Amount',
#        'Cash Flow', 'Net Income', 'Revenue', 'Expenditure', 'Profit Margin',
#        'Debt-to-Equity Ratio', 'Operating Expenses', 'Gross Profit',
#        'Transaction Volume', 'Processing Time (seconds)', 'Accuracy Score',
#        'Missing Data Indicator', 'Normalized Transaction Amount',
#        'Transaction Outcome'],
#       dtype='object')

# %%
data[['Transaction ID','Transaction Outcome']]
# Out:
#      Transaction ID  Transaction Outcome
# 0                 1                    1
# 1                 2                    1
# 2                 3                    1
# 3                 4                    1
# 4                 5                    1
# ..              ...                  ...
# 995             996                    0
# 996             997                    1
# 997             998                    1
# 998             999                    1
# 999            1000                    1
#
# [1000 rows x 2 columns]

# %%
data.columns
# Out:
# Index(['Transaction ID', 'Date', 'Account Type', 'Transaction Amount',
#        'Cash Flow', 'Net Income', 'Revenue', 'Expenditure', 'Profit Margin',
#        'Debt-to-Equity Ratio', 'Operating Expenses', 'Gross Profit',
#        'Transaction Volume', 'Processing Time (seconds)', 'Accuracy Score',
#        'Missing Data Indicator', 'Normalized Transaction Amount',
#        'Transaction Outcome'],
#       dtype='object')

# %%
data["TotalSales"]=data['Revenue']*data['Profit Margin']

# %%
data['TotalSales']
# Out:
# 0      1904.851219
# 1      1669.224038
# 2      2281.282200
# 3       966.637078
# 4      2524.203864
#           ...
# 995    2003.761557
# 996    1366.810422
# 997    1582.866295
# 998     957.083979
# 999    1849.442429
# Name: TotalSales, Length: 1000, dtype: float64

# %%
data.rename(columns= {"TotalSales":'Total Sales'})
# Out:
#      Transaction ID        Date Account Type  Transaction Amount  Cash Flow  \
# 0                 1  2025-01-01        Asset                1176       3184
# 1                 2  2025-01-02        Asset                1291       3221
# 2                 3  2025-01-03      Revenue                4966       3309
# 3                 4  2025-01-04      Expense                4641       1952
# 4                 5  2025-01-05      Expense                2305       2131
# ..              ...         ...          ...                 ...        ...
# 995             996  2027-09-23        Asset                2625       2655
# 996             997  2027-09-24        Asset                 676       1586
# 997             998  2027-09-25      Revenue                2758       3624
# 998             999  2027-09-26    Liability                 796       2063
# 999            1000  2027-09-27      Expense                3387       4041
#
# ...

# %%
data.columns
# Out:
# Index(['Transaction ID', 'Date', 'Account Type', 'Transaction Amount',
#        'Cash Flow', 'Net Income', 'Revenue', 'Expenditure', 'Profit Margin',
#        'Debt-to-Equity Ratio', 'Operating Expenses', 'Gross Profit',
#        'Transaction Volume', 'Processing Time (seconds)', 'Accuracy Score',
#        'Missing Data Indicator', 'Normalized Transaction Amount',
#        'Transaction Outcome', 'TotalSales'],
#       dtype='object')

# %%
data['Revenue']>400
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Name: Revenue, Length: 1000, dtype: bool

# %%
data.sort_values('Revenue', ascending=False)
# Out:
#      Transaction ID        Date Account Type  Transaction Amount  Cash Flow  \
# 111             112  2025-04-22        Asset                 341       1764
# 901             902  2027-06-21        Asset                3389       2992
# 227             228  2025-08-16    Liability                 293       3101
# 693             694  2026-11-25      Revenue                2270       4422
# 984             985  2027-09-12      Expense                2392       3826
# ..              ...         ...          ...                 ...        ...
# 21               22  2025-01-22      Expense                1358       3832
# 403             404  2026-02-08      Expense                2703       2916
# 270             271  2025-09-28    Liability                2034       2853
# 126             127  2025-05-07        Asset                3740        584
# 33               34  2025-02-03      Revenue                3879       1360
#
# ...

# %%
data.drop_duplicates()
# Out:
#      Transaction ID        Date Account Type  Transaction Amount  Cash Flow  \
# 0                 1  2025-01-01        Asset                1176       3184
# 1                 2  2025-01-02        Asset                1291       3221
# 2                 3  2025-01-03      Revenue                4966       3309
# 3                 4  2025-01-04      Expense                4641       1952
# 4                 5  2025-01-05      Expense                2305       2131
# ..              ...         ...          ...                 ...        ...
# 995             996  2027-09-23        Asset                2625       2655
# 996             997  2027-09-24        Asset                 676       1586
# 997             998  2027-09-25      Revenue                2758       3624
# 998             999  2027-09-26    Liability                 796       2063
# 999            1000  2027-09-27      Expense                3387       4041
#
# ...

# %%
data.groupby('Account Type')['Revenue'].mean()
# Out:
# Account Type
# Asset        2573.631373
# Expense      2696.517510
# Liability    2656.956000
# Revenue      2510.373950
# Name: Revenue, dtype: float64

# %%
data.groupby('Account Type').agg(
    {
        'Revenue':'mean'
    }
)
# Out:
#                   Revenue
# Account Type
# Asset         2573.631373
# Expense       2696.517510
# Liability     2656.956000
# Revenue       2510.373950
