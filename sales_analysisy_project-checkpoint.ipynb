# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd

orders=pd.read_csv(r"C:\Users\User\OneDrive\Documents\excel dashboard\orders.csv")
products=pd.read_csv(r"C:\Users\User\OneDrive\Documents\excel dashboard\products.csv")
customers=pd.read_csv(r"C:\Users\User\OneDrive\Documents\excel dashboard\customers.csv")

orders.head(2)
# Out:
#    Order_ID Customer_ID  Product_ID  Quantity  ... Delivery_Date Delivery_Time   Location     Occasion
# 0         1        C037          67         5  ...    05-03-2023      07:27:10  Bardhaman  Anniversary
# 1         2        C019          41         2  ...    13-11-2023      07:16:17     Jaipur       Diwali
#
# [2 rows x 10 columns]

# %%
products.head(2)
# Out:
#    Product_ID  Product_Name   Category  Price (INR)         Occasion                   Description
# 0           1    Magnam Set  Soft Toys         1935    All Occasions  Quam numquam iste sunt nemo.
# 1           2  Voluptas Box     Plants          441  Valentine's Day        At quaerat animi nemo.

# %%
customers.head(20)
# Out:
#    Customer_ID             Name  ...  Gender                                     Address
# 0         C001    Tara Krishnan  ...  Female  65/04\nDhawan Marg, Rajpur Sonarpur 590551
# 1         C002       Myra Edwin  ...  Female        H.No. 78\nSharaf Ganj\nIndore 928261
# 2         C003     Jayesh Lanka  ...    Male        H.No. 53, Krishna Ganj, Dhule-346480
# 3         C004      Tarini Bava  ...    Male                 145\nSibal, Rourkela-650344
# 4         C005       Hiran Kaul  ...    Male      34/168\nSachar Street\nBhatpara 002691
# 5         C006       Rania Mann  ...  Female           15/89, Dayal Chowk, Rohtak 586046
# 6         C007    Jayant Kamdar  ...    Male    H.No. 501\nGoswami Path, Bhilwara 482554
# 7         C008         Veer Ray  ...  Female      H.No. 589, Gala Circle, Nandyal-774484
# 8         C009     Ritvik Borah  ...  Female           28/64\nLanka Marg, Ramgarh 141634
# 9         C010     Darshit Dave  ...    Male     H.No. 21\nSinghal Path\nHindupur 170985
# 10        C011     Lagan Kapoor  ...  Female       53/710, Tailor Ganj, Gorakhpur-030540
# 11        C012     Onkar Mangat  ...    Male    H.No. 460, Sankar Ganj\nTadipatri 227246
# 12        C013  Manikya Goswami  ...  Female            382, Banerjee Ganj\nPatna 002103
# 13        C014   Indrans Shukla  ...  Female            67/61, Balan Nagar\nDehri-162882
# 14        C015      Romil Bajwa  ...  Female         890, Sathe Circle\nMoradabad 800838
# 15        C016     Amani Ganesh  ...    Male                667\nSom Marg\nRajkot 238865
# 16        C017      Advika Dhar  ...    Male   80/81, Varghese Chowk, Bidhannagar-928710
# 17        C018       Eva Vaidya  ...    Male       34/29\nManne Circle, Ahmedabad 929297
# 18        C019   Amira Sengupta  ...    Male             77\nDass Street\nSasaram-948992
# 19        C020   Samaira Ganesh  ...    Male           12, Khosla Chowk\nGopalpur-059682
#
# [20 rows x 7 columns]

# %%
order_products=pd.merge(orders,products, on="Product_ID")

# %%
order_products.head()
# Out:
#    Order_ID Customer_ID  Product_ID  ...  Price (INR)       Occasion_y                                        Description
# 0         1        C037          67  ...         1374      Anniversary                            Earum quos enim minima.
# 1         2        C019          41  ...         1977           Diwali                         Ab quisquam nobis ducimus.
# 2         3        C029          67  ...         1374      Anniversary                            Earum quos enim minima.
# 3         4        C012          14  ...         1915         Birthday                Incidunt hic vero esse saepe illum.
# 4         5        C078          58  ...         1492  Valentine's Day  Reiciendis nam omnis vel explicabo amet perfer...
#
# [5 rows x 15 columns]

# %%
full_data=pd.merge(order_products,customers, on="Customer_ID")

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        1000 non-null   int64
#  1   Customer_ID     1000 non-null   object
#  2   Product_ID      1000 non-null   int64
#  3   Quantity        1000 non-null   int64
#  4   Order_Date      1000 non-null   object
#  5   Order_Time      1000 non-null   object
#  6   Delivery_Date   1000 non-null   object
#  7   Delivery_Time   1000 non-null   object
#  8   Location        1000 non-null   object
#  9   Occasion_x      1000 non-null   object
#  10  Product_Name    1000 non-null   object
#  11  Category        1000 non-null   object
#  12  Price (INR)     1000 non-null   int64
#  13  Occasion_y      1000 non-null   object
#  14  Description     1000 non-null   object
#  15  Name            1000 non-null   object
#  16  City            1000 non-null   object
#  17  Contact_Number  1000 non-null   int64
#  18  Email           1000 non-null   object
#  19  Gender          1000 non-null   object
#  20  Address         1000 non-null   object
# dtypes: int64(5), object(16)
# memory usage: 164.2+ KB

# %%
full_data["revenue"]=full_data["Quantity"] * full_data["Price (INR)"]

# %%
total_revenue=full_data["revenue"].sum()

# %%
print("total_revenue",total_revenue)
# Out:
# total_revenue 3520984

# %%
total_orders=full_data["Order_ID"].nunique()

# %%
print("total_orders",total_orders)
# Out:
# total_orders 1000

# %%
average_order=total_revenue/total_orders

# %%
print(average_order)
# Out:
# 3520.984

# %%
top_products=full_data.groupby("Product_Name")["revenue"].sum().sort_values(ascending=False).head(5)

# %%
print(top_products)
# Out:
# Product_Name
# Magnam Set      121905
# Quia Gift       114476
# Dolores Gift    106624
# Harum Pack      101556
# Deserunt Box     97665
# Name: revenue, dtype: int64

# %%
top_customers=full_data.groupby("Customer_ID")["revenue"].sum().sort_values(ascending=False).head(5)

# %%
print(top_customers)
# Out:
# Customer_ID
# C020    75029
# C044    70409
# C045    61294
# C024    59666
# C099    53082
# Name: revenue, dtype: int64

# %%
full_data["Order_Date"]=pd.to_datetime(full_data["Order_Date"],dayfirst=True)

# %%
monthly_revenue=full_data.groupby(full_data["Order_Date"].dt.to_period("M"))["revenue"].sum()

# %%
print(monthly_revenue)
# Out:
# Order_Date
# 2023-01     95468
# 2023-02    704509
# 2023-03    511823
# 2023-04    140393
# 2023-05    150346
# 2023-06    157913
# 2023-07    135826
# 2023-08    737389
# 2023-09    136938
# 2023-10    151619
# 2023-11    449169
# 2023-12    149591
# Freq: M, Name: revenue, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
monthly_revenue.plot(kind="bar",title="monthly_revenue")
# Out:
# <Axes: title={'center': 'monthly_revenue'}, xlabel='Order_Date'>

# %% [markdown]
# # KPI Summary Report

# %% [markdown]
# ## Revenue KPIs

# %% [markdown]
# **Total Revenue**=3520984

# %% [markdown]
# **Total Orders**=1000

# %% [markdown]
# **Average Order**=3520.984

# %% [markdown]
# ## Top 5 ProductsByName
#
# Magnam Set
# Quia Gift
# Dolores Gift
# Harum Pack
# Deserunt Box

# %% [markdown]
# ## Top 5 Customers
#
#
#
# C020
# C044
# C045
# C024
# C099

# %% [markdown]
# # Monthly revnue

# %%
monthly_revenue.plot(kind="bar",title="monthly_revenue")
# Out:
# <Axes: title={'center': 'monthly_revenue'}, xlabel='Order_Date'>

# %% [markdown]
# ## Buisness Insights
# ### highest sales in August
# ### top category is sweets
# ### Samaira Ganesh is our top customer
