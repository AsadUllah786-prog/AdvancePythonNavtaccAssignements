# %%
try :
    print(x)
except NameError:
    print("variable is not defined")
except :
    print("something else went wrong")
# Out:
# variable is not defined

# %%
try :
    print("hello")
except:
    print("some thing went wrong")
else:
    print("the code executed successfully")
# Out:
# hello
# the code executed successfully

# %%
try:
    print(x)
except:
    print("something went wrong")
finally:
    print("try except is executed successfully")
# Out:
# something went wrong
# try except is executed successfully

# %%
try:
    f=open("demofile.txt")
    try:
        f.write()
    except:
        print("we can not write to this file")
    finally:
        f.close()
except:
    print("something mmight be wrong")
# Out:
# something mmight be wrong

# %%
x=-1

if x<0:
    raise Exception ("you can not entered number less then xero")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 x=-1
#       3 if x<0:
# ----> 4     raise Exception ("you can not entered number less then xero")
#
# Exception: you can not entered number less then xero

# %%
x="hello"

if not type(x) is int:
    raise TypeError ("THE NUMBER MUST BE INTEGER")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 x="hello"
#       3 if not type(x) is int:
# ----> 4     raise TypeError ("THE NUMBER MUST BE INTEGER")
#
# TypeError: THE NUMBER MUST BE INTEGER

# %%
y = True
while y == True:
  x = input("Enter a number:")
  try:
    x = float(x);
    y = False
  except:
    print("Wrong input, please try again.")

print("Thank you!")
# Out:
# Enter a number: ASAD
# Wrong input, please try again.
# Enter a number: 12
# Thank you!

# %%
print("user collection data file")
name=input("enter your name")
a=True
while a==True:
    age=input("enter your age")
    try:
        age=int(age)
        a=False
    except:
        print("please enter an integer value")
    salary=input("enter your salary")
    try:
        salary=float(salary)
        a=False
    except:
        print("enter your salary in float")
print(f"hello {name} your age is {age} and your salary is {salary}")
# Out:
# user collection data file
# enter your name Asad
# enter your age 18
# enter your salary 12.5
# hello Asad your age is 18 and your salary is 12.5
