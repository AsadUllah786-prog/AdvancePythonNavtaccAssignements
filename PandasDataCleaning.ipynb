# %%
import pandas as pd

# %%
df.shape
# Out:
# (1000, 18)

# %%
df.head(5)
# Out:
#    Transaction ID        Date Account Type  Transaction Amount  Cash Flow  \
# 0               1  2025-01-01        Asset                1176       3184
# 1               2  2025-01-02        Asset                1291       3221
# 2               3  2025-01-03      Revenue                4966       3309
# 3               4  2025-01-04      Expense                4641       1952
# 4               5  2025-01-05      Expense                2305       2131
#
#    Net Income  Revenue  Expenditure  Profit Margin  Debt-to-Equity Ratio  \
# 0        2174     3137         1823       0.607221              2.067004
# 1        3236     4694         2746       0.355608              2.347537
# 2        3689     3363         3102       0.678347              1.901003
# 3         245     4373          808       0.221047              0.934125
# 4        2037     4956          644       0.509323              1.061178
#
#    Operating Expenses  Gross Profit  Transaction Volume  \
# ...

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (1000, 18)

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Account Type', 'Transaction Amount',
#        'Cash Flow', 'Net Income', 'Revenue', 'Expenditure', 'Profit Margin',
#        'Debt-to-Equity Ratio', 'Operating Expenses', 'Gross Profit',
#        'Transaction Volume', 'Processing Time (seconds)', 'Accuracy Score',
#        'Missing Data Indicator', 'Normalized Transaction Amount',
#        'Transaction Outcome'],
#       dtype='object')

# %%
df=df.drop(columns=["Processing Time (seconds)","Accuracy Score","Missing Data Indicator","Normalized Transaction Amount"])

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Account Type', 'Transaction Amount',
#        'Cash Flow', 'Net Income', 'Revenue', 'Expenditure', 'Profit Margin',
#        'Debt-to-Equity Ratio', 'Operating Expenses', 'Gross Profit',
#        'Transaction Volume', 'Transaction Outcome'],
#       dtype='object')

# %%
df["Operating Expenses"]
# Out:
# 0      4098
# 1      3872
# 2      4780
# 3      4948
# 4      3289
#        ...
# 995    2240
# 996    3317
# 997    2494
# 998    4277
# 999    1658
# Name: Operating Expenses, Length: 1000, dtype: int64

# %%
df.convert_dtypes(convert_string="Transaction Outcome")
# Out:
#      Transaction ID        Date Account Type  Transaction Amount  Cash Flow  \
# 0                 1  2025-01-01        Asset                1176       3184
# 1                 2  2025-01-02        Asset                1291       3221
# 2                 3  2025-01-03      Revenue                4966       3309
# 3                 4  2025-01-04      Expense                4641       1952
# 4                 5  2025-01-05      Expense                2305       2131
# ..              ...         ...          ...                 ...        ...
# 995             996  2027-09-23        Asset                2625       2655
# 996             997  2027-09-24        Asset                 676       1586
# 997             998  2027-09-25      Revenue                2758       3624
# 998             999  2027-09-26    Liability                 796       2063
# 999            1000  2027-09-27      Expense                3387       4041
#
# ...

# %%
for x in df.index:
    if (x,["Transaction Outcome"])==1:
        df["Transaction Outcome"].str.replace("Yes")
    else:
        df["Transaction Outcome"].str.replace("No")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 5
#       3     df["Transaction Outcome"].str.replace("Yes")
#       4 else:
# ----> 5     df["Transaction Outcome"].str.replace("No")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6318, in NDFrame.__getattr__(self, name)
#    6311 if (
#    6312     name not in self._internal_names_set
#    6313     and name not in self._metadata
#    6314     and name not in self._accessors
#    6315     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316 ):
#    6317     return self[name]
# -> 6318 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Transaction ID        1000 non-null   int64
#  1   Date                  1000 non-null   object
#  2   Account Type          1000 non-null   object
#  3   Transaction Amount    1000 non-null   int64
#  4   Cash Flow             1000 non-null   int64
#  5   Net Income            1000 non-null   int64
#  6   Revenue               1000 non-null   int64
#  7   Expenditure           1000 non-null   int64
#  8   Profit Margin         1000 non-null   float64
#  9   Debt-to-Equity Ratio  1000 non-null   float64
#  10  Operating Expenses    1000 non-null   int64
#  11  Gross Profit          1000 non-null   int64
#  12  Transaction Volume    1000 non-null   int64
#  13  Transaction Outcome   1000 non-null   int64
# dtypes: float64(2), int64(10), object(2)
# ...

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\User\Downloads\accounting_data.csv")

# %%
df.head()
# Out:
#    Transaction ID        Date Account Type  Transaction Amount  Cash Flow  \
# 0               1  2025-01-01        Asset                1176       3184
# 1               2  2025-01-02        Asset                1291       3221
# 2               3  2025-01-03      Revenue                4966       3309
# 3               4  2025-01-04      Expense                4641       1952
# 4               5  2025-01-05      Expense                2305       2131
#
#    Net Income  Revenue  Expenditure  Profit Margin  Debt-to-Equity Ratio  \
# 0        2174     3137         1823       0.607221              2.067004
# 1        3236     4694         2746       0.355608              2.347537
# 2        3689     3363         3102       0.678347              1.901003
# 3         245     4373          808       0.221047              0.934125
# 4        2037     4956          644       0.509323              1.061178
#
#    Operating Expenses  Gross Profit  Transaction Volume  \
# ...

# %%
df.tail()
# Out:
#      Transaction ID        Date Account Type  Transaction Amount  Cash Flow  \
# 995             996  2027-09-23        Asset                2625       2655
# 996             997  2027-09-24        Asset                 676       1586
# 997             998  2027-09-25      Revenue                2758       3624
# 998             999  2027-09-26    Liability                 796       2063
# 999            1000  2027-09-27      Expense                3387       4041
#
#      Net Income  Revenue  Expenditure  Profit Margin  Debt-to-Equity Ratio  \
# 995        2152     3480         3974       0.575794              1.225116
# 996         472     3363         1952       0.406426              1.742689
# 997        2787     2702         3778       0.585813              2.290615
# 998        3203     3855         1266       0.248271              2.229671
# 999        2545     4521          831       0.409078              2.353535
#
# ...

# %%
df.shape
# Out:
# (1000, 18)

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Account Type', 'Transaction Amount',
#        'Cash Flow', 'Net Income', 'Revenue', 'Expenditure', 'Profit Margin',
#        'Debt-to-Equity Ratio', 'Operating Expenses', 'Gross Profit',
#        'Transaction Volume', 'Processing Time (seconds)', 'Accuracy Score',
#        'Missing Data Indicator', 'Normalized Transaction Amount',
#        'Transaction Outcome'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Transaction ID                 1000 non-null   int64
#  1   Date                           1000 non-null   object
#  2   Account Type                   1000 non-null   object
#  3   Transaction Amount             1000 non-null   int64
#  4   Cash Flow                      1000 non-null   int64
#  5   Net Income                     1000 non-null   int64
#  6   Revenue                        1000 non-null   int64
#  7   Expenditure                    1000 non-null   int64
#  8   Profit Margin                  1000 non-null   float64
#  9   Debt-to-Equity Ratio           1000 non-null   float64
#  10  Operating Expenses             1000 non-null   int64
#  11  Gross Profit                   1000 non-null   int64
# ...

# %%
df.describe().corr()
# Out:
#                                Transaction ID  Transaction Amount  Cash Flow  \
# Transaction ID                       1.000000            0.651334   0.630279
# Transaction Amount                   0.651334            1.000000   0.994980
# Cash Flow                            0.630279            0.994980   1.000000
# Net Income                           0.676487            0.998611   0.996209
# Revenue                              0.636208            0.998896   0.998464
# Expenditure                          0.693500            0.997929   0.992938
# Profit Margin                        0.520591           -0.308483  -0.327984
# Debt-to-Equity Ratio                 0.522067           -0.306833  -0.326328
# Operating Expenses                   0.654277            0.999750   0.995375
# Gross Profit                         0.690707            0.998450   0.993362
# Transaction Volume                   0.526219           -0.302187  -0.321727
# ...

# %%
df.isna().sum()
# Out:
# Transaction ID                   0
# Date                             0
# Account Type                     0
# Transaction Amount               0
# Cash Flow                        0
# Net Income                       0
# Revenue                          0
# Expenditure                      0
# Profit Margin                    0
# Debt-to-Equity Ratio             0
# Operating Expenses               0
# Gross Profit                     0
# Transaction Volume               0
# Processing Time (seconds)        0
# Accuracy Score                   0
# Missing Data Indicator           0
# Normalized Transaction Amount    0
# Transaction Outcome              0
# dtype: int64

# %%
df.fillna("ASad")
# Out:
#      Transaction ID        Date Account Type  Transaction Amount  Cash Flow  \
# 0                 1  2025-01-01        Asset                1176       3184
# 1                 2  2025-01-02        Asset                1291       3221
# 2                 3  2025-01-03      Revenue                4966       3309
# 3                 4  2025-01-04      Expense                4641       1952
# 4                 5  2025-01-05      Expense                2305       2131
# ..              ...         ...          ...                 ...        ...
# 995             996  2027-09-23        Asset                2625       2655
# 996             997  2027-09-24        Asset                 676       1586
# 997             998  2027-09-25      Revenue                2758       3624
# 998             999  2027-09-26    Liability                 796       2063
# 999            1000  2027-09-27      Expense                3387       4041
#
# ...

# %%
df.fillna(df.median)
# Out:
#      Transaction ID        Date Account Type  Transaction Amount  Cash Flow  \
# 0                 1  2025-01-01        Asset                1176       3184
# 1                 2  2025-01-02        Asset                1291       3221
# 2                 3  2025-01-03      Revenue                4966       3309
# 3                 4  2025-01-04      Expense                4641       1952
# 4                 5  2025-01-05      Expense                2305       2131
# ..              ...         ...          ...                 ...        ...
# 995             996  2027-09-23        Asset                2625       2655
# 996             997  2027-09-24        Asset                 676       1586
# 997             998  2027-09-25      Revenue                2758       3624
# 998             999  2027-09-26    Liability                 796       2063
# 999            1000  2027-09-27      Expense                3387       4041
#
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Date, Account Type, Transaction Amount, Cash Flow, Net Income, Revenue, Expenditure, Profit Margin, Debt-to-Equity Ratio, Operating Expenses, Gross Profit, Transaction Volume, Processing Time (seconds), Accuracy Score, Missing Data Indicator, Normalized Transaction Amount, Transaction Outcome]
# Index: []

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Date, Account Type, Transaction Amount, Cash Flow, Net Income, Revenue, Expenditure, Profit Margin, Debt-to-Equity Ratio, Operating Expenses, Gross Profit, Transaction Volume, Processing Time (seconds), Accuracy Score, Missing Data Indicator, Normalized Transaction Amount, Transaction Outcome]
# Index: []

# %%
df.drop_duplicates()
# Out:
#      Transaction ID        Date Account Type  Transaction Amount  Cash Flow  \
# 0                 1  2025-01-01        Asset                1176       3184
# 1                 2  2025-01-02        Asset                1291       3221
# 2                 3  2025-01-03      Revenue                4966       3309
# 3                 4  2025-01-04      Expense                4641       1952
# 4                 5  2025-01-05      Expense                2305       2131
# ..              ...         ...          ...                 ...        ...
# 995             996  2027-09-23        Asset                2625       2655
# 996             997  2027-09-24        Asset                 676       1586
# 997             998  2027-09-25      Revenue                2758       3624
# 998             999  2027-09-26    Liability                 796       2063
# 999            1000  2027-09-27      Expense                3387       4041
#
# ...

# %%
df.interpolate()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11224\4002874584.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#      Transaction ID        Date Account Type  Transaction Amount  Cash Flow  \
# 0                 1  2025-01-01        Asset                1176       3184
# 1                 2  2025-01-02        Asset                1291       3221
# 2                 3  2025-01-03      Revenue                4966       3309
# 3                 4  2025-01-04      Expense                4641       1952
# 4                 5  2025-01-05      Expense                2305       2131
# ..              ...         ...          ...                 ...        ...
# 995             996  2027-09-23        Asset                2625       2655
# 996             997  2027-09-24        Asset                 676       1586
# ...

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Account Type', 'Transaction Amount',
#        'Cash Flow', 'Net Income', 'Revenue', 'Expenditure', 'Profit Margin',
#        'Debt-to-Equity Ratio', 'Operating Expenses', 'Gross Profit',
#        'Transaction Volume', 'Processing Time (seconds)', 'Accuracy Score',
#        'Missing Data Indicator', 'Normalized Transaction Amount',
#        'Transaction Outcome'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11224\3624906849.py in ?()
# ----> 1 df[["Account Type","Revenue"]].group_by(["Account Type","Revenue"])
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'group_by'
