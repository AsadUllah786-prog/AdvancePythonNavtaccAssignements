# %%
import pandas as pd
import requests as r 
response= r.get("https://fake-json-api.mock.beeceptor.com/users")
userresponse=response.json()
# print(userresponse)
df=pd.DataFrame(userresponse)
# print(df)
# df.head()
df.columns
df.isnull().sum()
df.dtypes
df.describe(include="object")
# Out:
#                   name                    company      username  \
# count               10                         10            10
# unique              10                         10            10
# top     Judson Padberg  Nolan, Herzog and Okuneva  Earlene_Moen
# freq                 1                          1             1
#
#                     email                address    zip     state     country  \
# count                  10                     10     10        10          10
# unique                 10                     10     10         9          10
# top     Diego55@gmail.com  11015 Cornelius Trail  74924  Michigan  Antarctica
# freq                    1                      1      1         2           1
#
#                        phone                                       photo
# count                     10                                          10
# unique                    10                                          10
# ...

# %%
headers={
    'Content-Type':'application/json',
}
credentials={'email':'john@mail.com','password':'changeme'}
userprofileurl='https://api.escuelajs.co/api/v1/auth/login'
response=r.post(userprofileurl,credentials,headers)
print(response.json())

access_token='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOjEsImlhdCI6MTc3NTQ4NzYzOCwiZXhwIjoxNzc3MjE1NjM4fQ.Xg6noodFfCfTuKIe-yiEvHMZbkDSxWAt82jP04lSy2E'
# Out:
#   Cell In[29], line 7
#     access_token=response.json(){'access_token'}
#                                 ^
# SyntaxError: invalid syntax

# %%
headers={
     'Authorization':'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOjEsImlhdCI6MTc3NTQ4NzYzOCwiZXhwIjoxNzc3MjE1NjM4fQ.Xg6noodFfCfTuKIe-yiEvHMZbkDSxWAt82jP04lSy2E'
}
credentials={'email':'john@mail.com','password':'changeme'}
userprofileurl='https://api.escuelajs.co/api/v1/auth/profile'
response=r.get(userprofileurl,headers=headers)
data=response.json()

# %%
df = pd.DataFrame([data])

# %%
df.to_csv("userInfo")
print("userInfo saved successfully")
# Out:
# userInfo saved successfully

# %%
df.head()
# Out:
#    id          email  password  name      role  \
# 0   1  john@mail.com  changeme  Jhon  customer
#
#                             avatar                creationAt  \
# 0  https://i.imgur.com/LDOO4Qs.jpg  2026-04-06T03:15:21.000Z
#
#                   updatedAt
# 0  2026-04-06T03:15:21.000Z

# %%
import requests

url = "https://i.imgur.com/LDOO4Qs.jpeg"

response = requests.get(url)



with open("avatar.jpeg", "wb") as file:
        file.write(response.content)
        print("Image downloaded successfully")
# Out:
# Image downloaded successfully

# %%
# !pip install selenium
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
