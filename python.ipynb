# %%
print("hello world")
# Out:
# hello world

# %%
with open("test.txt","a") as f:
    f.write("this is my new file\nilove myself")

with open("test.txt","rt") as f :
    for x in f:
        print(x)
# Out:
# this is my new filethis is my new file
#
# ilove myself

# %%
from datetime import date, datetime, timedelta, timezone
import calendar as cal
from zoneinfo  import ZoneInfo
import time

# %%
today = date.today()
today
# Out:
# datetime.date(2025, 9, 24)

# %%
today.ctime()
today.isoformat()
# Out:
# '2025-09-24'

# %%
today.timetuple()
# Out:
# time.struct_time(tm_year=2025, tm_mon=9, tm_mday=24, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=267, tm_isdst=-1)

# %%
today.weekday()
# Out:
# 2

# %%
print(cal.day_name[today.weekday()])
# Out:
# Wednesday

# %%
 time.ctime()
# Out:
# 'Wed Sep 24 05:53:26 2025'

# %%
 time.daylight
# Out:
# 1
