# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r"C:\Users\User\OneDrive\Desktop\Ailabs\canada_pci (1).csv")

# %%
print(df.head())
# Out:
#    year          pci
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
plt.xlabel("Year")
plt.ylabel("per capita income")
# Out:
# Text(0, 0.5, 'per capita income')

# %%
plt.scatter(df.year,df.pci)

# %%
model=LinearRegression()

# %%
model.fit(df[["year"]],df.pci)
# Out:
# LinearRegression()

# %%
prediction_2022 = model.predict(pd.DataFrame({'year': [2022]}))

# %%
print("Predicted PCI for 2021:", prediction_2022[0])
# Out:
# Predicted PCI for 2021: 42945.624244862935

# %%
plt.plot(df.year, model.predict(df[['year']]), color='red')

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.mplot3d import axes3d

# %%
# define the function to be minimizes

def f(x,y):
    return x**2 + y**2

# %%
def dx(x,y):
    return 2*x

def dy(x,y):
    return 2*y

# %%
def gradientDescent(start_x,start_y,learning_rate,num_iterations):
    x = start_x
    y = start_y
    history = []

    for i in range(num_iterations):
        grad_x=dx(x,y)
        grad_y=dy(x,y)

        x = x - learning_rate * grad_x
        y = y - learning_rate * grad_y


        history.append(x,y,f(x,y))

    return x,y, f(x,y),history

# %%
x_range = np.arange(-10, 10, 0.1)
y_range = np.arange(-10, 10, 0.1)

# %%
X, Y = np.meshgrid(x_range, y_range)

# %%
Z=f(X,Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 Z=f(X,Y)
#
# NameError: name 'f' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


# Define the function to be minimized (a simple quadratic function)
def f(x, y):
    return x ** 2 + y ** 2


# Define the partial derivatives of the function with respect to x and y
def df_dx(x, y):
    return 2 * x


def df_dy(x, y):
    return 2 * y


# Define the gradient descent algorithm
def gradient_descent(start_x, start_y, learning_rate, num_iterations):
    # Initialize the parameters
    x = start_x
    y = start_y
    history = []

    # Perform the gradient descent iterations
    for i in range(num_iterations):
        # Calculate the gradients
        grad_x = df_dx(x, y)
        grad_y = df_dy(x, y)

        # Update the parameters
        x = x - learning_rate * grad_x
        y = y - learning_rate * grad_y

        # Save the history of the parameters
        history.append((x, y, f(x, y)))

    return x, y, f(x, y), history


# Define the meshgrid for plotting the function
x_range = np.arange(-10, 10, 0.1)
y_range = np.arange(-10, 10, 0.1)
X, Y = np.meshgrid(x_range, y_range)
Z = f(X, Y)

# Perform gradient descent and plot the results
start_x, start_y = 8, 8
learning_rate = 0.1
num_iterations = 20
x_opt, y_opt, f_opt, history = gradient_descent(start_x, start_y, learning_rate, num_iterations)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='coolwarm')
ax.scatter(*zip(*history), c='r', marker='o')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d


def f(x,y):
    return x**2+y**2

def df_x(x,y):

    return 2*x

def df_y(x,y):
    return 2*y

def gradientDescent(startx,starty,learningrate,num_iterations):
    x=start_x
    y=start_y
    histor=[]

    for i in range(num_iterations):
        grad_x=df_x(x,y)
        grad_y=df_y(x,y)


        x=x-learning_rate*grad_x
        y=y-learning_rate*grad_y

        history.append((x, y, f(x, y)))

      return x, y, f(x, y), history

xa=np.arange(-10, 10, 0.1)
ya=np.arange(-10, 10, 0.1)
X, Y = np.meshgrid(x_range, y_range)
Z = f(X, Y)

# %%
print("i love programming")
# Out:
# i love programming

# %%
print("i am the master of python")
# Out:
# i am the master of python

# %% [markdown]
# # step 1:Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import  LinearRegression
print("Asad is a master of pyhton and automations and inventions")
# Out:
# Asad is a master of pyhton and automations and inventions

# %% [markdown]
# # step 2: Load the dataset

# %%
data=pd.read_csv(r"C:\Users\User\OneDrive\Desktop\Ailabs\house_prices (1).csv")

# %% [markdown]
# # step 3: Explore the dataset

# %%
print(data.head())
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
data.shape
# Out:
# (5, 2)

# %%
data.describe()
# Out:
#               Area          Price
# count     5.000000       5.000000
# mean   3280.000000  626000.000000
# std     540.370243   74949.983322
# min    2600.000000  550000.000000
# 25%    3000.000000  565000.000000
# 50%    3200.000000  610000.000000
# 75%    3600.000000  680000.000000
# max    4000.000000  725000.000000

# %%
plt.scatter(data.Area,data.Price)
plt.xlabel("Area")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
#  # Step 4:After Exploration select the model

# %%
model=LinearRegression()

# %%
model.fit(data[["Area"]],data.Price)
# Out:
# LinearRegression()

# %%
predictionfor5000=model.predict([[5000]])
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("prediction asad is best python programmer is",predictionfor5000)
# Out:
# prediction asad is best python programmer is [859554.79452055]

# %%
print(model.coef_)
# Out:
# [135.78767123]

# %%
print(model.intercept_)
# Out:
# 180616.43835616432

# %%
plt.plot(model.predict([[5000]]))
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.xlabel("Area (sq.ft.)")
plt.ylabel("Price ($)")
plt.scatter(data.Area, data.Price, color="red")
plt.plot(data.Area, model.predict(data[['Area']]), color="blue")
plt.show()

# %%
R2=model.score(data.Area,data.Price)
print(R2)
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 R2=model.score(data.Area,data.Price)
#       2 print(R2)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:638, in RegressorMixin.score(self, X, y, sample_weight)
#     596 """Return :ref:`coefficient of determination <r2_score>` on test data.
#     597
#     598 The coefficient of determination, :math:`R^2`, is defined as
#    (...)    633 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     634 """
#     636 from .metrics import r2_score
# --> 638 y_pred = self.predict(X)
# ...

# %%
X = data[['Area']]
y = data['Price']


R2scr=model.score(X,y)

# %%
print(R2scr)
# Out:
# 0.9584301138199486

# %% [markdown]
# # Asad is ready to invent a new thing for humanity

# %% [markdown]
# # File Handling

# %%
import pandas as pd
import json

# %%
with open("students.txt","r") as file:
    feedback=file.readlines()
