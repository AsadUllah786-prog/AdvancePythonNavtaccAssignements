# %% [markdown]
# # Temperature Converter

# %%
print("Temperature Calculator")

print("1. Celsius")
print("2. Fahrenheit")
print("3. Kelvin")

while True:
    

    choice = input("Enter your choice: 1. Celsius, 2. Fahrenheit,3. Kelvin,4 Exit")
    
    if choice == "1":
    
        celsius = float(input("Enter temperature in Celsius: "))
    
        fahrenheit = (celsius * 9/5) + 32
        kelvin = celsius + 273.15
    
        print("Fahrenheit =", fahrenheit)
        print("Kelvin =", kelvin)
    
    
    elif choice == "2":
    
        fahrenheit = float(input("Enter temperature in Fahrenheit: "))
    
        celsius = (fahrenheit - 32) * 5/9
        kelvin = celsius + 273.15
    
        print("Celsius =", celsius)
        print("Kelvin =", kelvin)
    
    
    elif choice == "3":
    
        kelvin = float(input("Enter temperature in Kelvin: "))
    
        celsius = kelvin - 273.15
        fahrenheit = (celsius * 9/5) + 32
    
        print("Celsius =", celsius)
        print("Fahrenheit =", fahrenheit)

    elif choice=="4":
        print("thanks for using temperature converter")
        break
    
    
    else:
        print("invalid choice")
# Out:
# Temperature Calculator
# 1. Celsius
# 2. Fahrenheit
# 3. Kelvin
# Enter your choice: 1. Celsius, 2. Fahrenheit,3. Kelvin,4 Exit 1
# Enter temperature in Celsius:  20
# Fahrenheit = 68.0
# Kelvin = 293.15
# Enter your choice: 1. Celsius, 2. Fahrenheit,3. Kelvin,4 Exit 4
# thanks for using temperature converter
