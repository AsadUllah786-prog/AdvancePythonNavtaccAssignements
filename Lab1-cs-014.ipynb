# %%
print("hello world")
# Out:
# hello world

# %%
age

print(type(age))
# Out:
# <class 'int'>

# %% [raw]
# 👉 Task 2.1: Create variables for:
# •	Your favorite programming language
# •	Your university name
# •	Your age
# Print them in a sentence like:
# I study at UVAS, I am 20 years old, and my favorite language is Python.
# ________________________________________

# %%
ProgrammingLanguage="python"
universityName="Uvas"
age=20

print(f"i study at {universityName} , i am {age} years old, and my favourite language is {ProgrammingLanguage}")
# Out:
# i study at Uvas , i am 20 years old, and my favourite language is python

# %% [raw]
# 👉 Task 3.1 (Challenge):
# •	Ask the user for distance (km) and time (hours).
# •	Calculate speed = distance / time.
# •	Print result with 2 decimal places.
# •	Add error handling: if time = 0, print "Error: Time cannot be zero!".
# ________________________________________

# %% [raw]
# distance=float(input("enter the distance you want to travelled in km"))
# time=float(input("enter time in hours"))
#
# if (time==0):
#     print("time can not be zero")
# else:
#     speed=distance/time
#     print(speed)

# %% [raw]
# Task 4.1:
# •	Take a sentence from the user.
# •	Print:
# 1.	The sentence reversed.
# 2.	The number of vowels in the sentence.
# 3.	Whether the word "AI" appears in it (True/False).

# %%
sentence=input("please enter a sentence:")

reversed_Sentence=sentence[::-1]
vowels="aeiouAEIOU"

vovelCount=sum(1 for ch in sentence if ch in vowels)
print(vovelCount)


Ai_in_sentence="AI" in sentence
if (Ai_in_sentence):
    print("yes there is the word AI in sentence ")
else:
    print("no AI present")
# Out:
# please enter a sentence: asad
# 2
# no AI present

# %% [raw]
# 👉 Task 4.2:
# •	Take a sentence as input from user.
# •	Print:
# 1.	First 5 characters
# 2.	Last 3 characters
# 3.	Sentence in uppercase

# %%
sentence=input("enter a sentence")
firstFive=sentence[:5]
print(firstFive)

lastThree=sentence[-1:-4:-1]
print(lastThree)

upperCase=sentence.upper()
print(upperCase)
# Out:
# enter a sentence Assas
# Assas
# sas
# ASSAS

# %% [raw]
# Task 2 : AI Readiness Calculator
# 1.	Ask user for:
# o	Name
# o	Age
# o	Hours studied per week
# o	Favorite programming language
# o	GPA
# 2.	Perform calculations:
# o	If GPA ≥ 3.5 and Hours ≥ 10 → "Ready for AI Research!"
# o	Else if GPA ≥ 2.5 → "Can improve with more practice."
# .y8bnmu Task 2 : AI Readiness Calculator
# 1.	Ask user for:
# o	Name
# o	Age
# o	Hours studied per week
# o	Favorite programming language
# o	GPA
# 2.	Perform calculations:
# o	If GPA ≥ 3.5 and Hours ≥ 10 → "Ready for AI Research!"
# o	Else if GPA ≥ 2.5 → "Can improve with more practice."
# o	Else → "Focus on basics first."
# 3.	Print formatted profile:
# 4.	Student Profile:
# 5.	Name: Ayesha, Age: 20
# 6.	Favorite Language: Python
# 7.	Weekly Study Hours: 12
# 8.	GPA: 3.7
# 9.	Status: Ready for AI Research!
#
# 6r6bn,67m8utb6kuno	Else → "Focus on basics first."
# 3.	Print formatted profile:
# 4.	Student Profile:
# 5.	Name: Ayesha, Age: 20
# 6.	Favorite Language: Python
# 7.	Weekly Study Hours: 12
# 8.	GPA: 3.7
# 9.	Status: Ready for AI Research!
