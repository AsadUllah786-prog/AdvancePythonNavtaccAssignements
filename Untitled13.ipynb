# %%
from logic import Symbol, Not, And, Or, Implication, model_check

# %%
rain = Symbol("rain")
hagrid = Symbol("hagrid")
dumbledore = Symbol("dumbledore")

knowledge = And(
    Implication(Not(rain), hagrid),
    Or(hagrid, dumbledore),
    Not(And(hagrid, dumbledore)),
    dumbledore
)

query = (rain)
print(model_check(knowledge, Not (query)))
# Out:
# Pretend we’re checking the KB logically...
# True

# %%
# !python harry.py
# Out:
# Knowledge Base: ((NOT rain -> hagrid) AND (rain -> hagrid) AND (hagrid OR dumbledore) AND NOT (hagrid AND dumbledore) AND dumbledore)
# Query: rain
# Does KB entail the query? True
