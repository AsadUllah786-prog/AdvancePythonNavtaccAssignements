# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\User\OneDrive\Desktop\SuperStore_Sales_Dataset.csv")

# %%
df.head()
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
# 1              4919  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
# 2              4920  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
# 3              3074  CA-2019-125206  03-01-2019  05-01-2019     First Class
# 4              8604  US-2019-116365  03-01-2019  08-01-2019  Standard Class
#
#   Customer ID      Customer Name    Segment        Country          City  ...  \
# 0    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 2    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 3    LR-16915       Lena Radford   Consumer  United States   Los Angeles  ...
# 4    CA-12310  Christine Abelman  Corporate  United States   San Antonio  ...
#
#           Category Sub-Category  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID+O6G3A1:R6', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Profit', 'Returns', 'Payment Mode', 'ind1',
#        'ind2'],
#       dtype='object')

# %%
df=df.drop(columns=['Row ID+O6G3A1:R6'])

# %%
df.shape
# Out:
# (5901, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sales     5901 non-null   float64
#  1   Quantity  5901 non-null   int64
#  2   Profit    5901 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 138.4 KB

# %%
df=df.select_dtypes(include="number")

# %%
df
# Out:
#          Sales  Quantity   Profit
# 0       73.940         1  28.2668
# 1      173.940         3  38.2668
# 2      231.980         2  67.2742
# 3      114.460         2  28.6150
# 4       30.080         2  -5.2640
# ...        ...       ...      ...
# 5896   213.136         4  12.1176
# 5897   295.904         2   4.5188
# 5898   388.024         3  -0.6048
# 5899   462.776         3  19.7910
# 5900  2975.510         3  -0.6048
#
# [5901 rows x 3 columns]

# %%
df.corr()
# Out:
#              Sales  Quantity    Profit
# Sales     1.000000  0.202420  0.325915
# Quantity  0.202420  1.000000  0.074761
# Profit    0.325915  0.074761  1.000000

# %%
sns.heatmap(df.corr())

# %%
df=pd.read_csv(r"C:\Users\User\OneDrive\Desktop\SuperStore_Sales_Dataset.csv")

# %%
df.isnull().sum()
# Out:
# Row ID+O6G3A1:R6       0
# Order ID               0
# Order Date             0
# Ship Date              0
# Ship Mode              0
# Customer ID            0
# Customer Name          0
# Segment                0
# Country                0
# City                   0
# State                  0
# Region                 0
# Product ID             0
# Category               0
# Sub-Category           0
# Product Name           0
# Sales                  0
# Quantity               0
# Profit                 0
# Returns             5614
# Payment Mode           0
# ind1                5901
# ind2                5901
# dtype: int64

# %%
df=df.drop(columns=["Returns","ind1","ind2"])

# %%
df=df.groupby("Region").mean(["Sales","Quantity","Profit"]).sort_values(by="Sales" ,ascending=False)
df.transpose()
# Out:
# Region                   West        South         East      Central
# Row ID+O6G3A1:R6  5095.369279  5133.190118  4941.020735  4946.832006
# Sales              274.824330   270.806747   266.726698   246.927968
# Quantity             3.839032     3.790548     3.703199     3.793628
# Profit              35.696980    28.519566    31.635322    19.876906

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df=df.select_dtypes(include="float")

# %%
df=df.drop(columns=["Row ID+O6G3A1:R6"])

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df["Quantity"].max()
# Out:
# np.float64(3.8390320883745397)

# %% [markdown]
# # Step 1 Libraries Import is the first step

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # step 2 load the dataset

# %%
data=pd.read_csv("C:\Users\User\Downloads\drive-download--1-001\ecommerce_data.csv")
