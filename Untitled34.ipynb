# %%
# ===========================
# Music Recommendation Streamlit App
# ===========================

import streamlit as st
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns

# ---------------------------
# Step 1: Load Dataset
# ---------------------------
@st.cache_data
def load_data():
    data = pd.read_csv('tcc_ceds_music.csv')
    data['combined_features'] = data['track_name'].astype(str) + " " + \
                                data['artist_name'].astype(str) + " " + \
                                data['genre'].astype(str)
    return data

data = load_data()

# ---------------------------
# Step 2: Compute TF-IDF & Cosine Similarity
# ---------------------------
@st.cache_data
def compute_similarity(data):
    tfidf = TfidfVectorizer(stop_words='english')
    tfidf_matrix = tfidf.fit_transform(data['combined_features'])
    cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
    return cosine_sim

cosine_sim = compute_similarity(data)

# ---------------------------
# Step 3: Recommendation Function
# ---------------------------
def get_recommendations(song_title, data, cosine_sim, top_n=10):
    idx = data[data['track_name'].str.lower() == song_title.lower()].index
    if len(idx) == 0:
        st.warning(f"Song '{song_title}' not found in the dataset.")
        return pd.DataFrame()
    
    idx = idx[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:top_n+1]
    song_indices = [i[0] for i in sim_scores]
    
    return data.iloc[song_indices][['track_name', 'artist_name', 'genre']]

# ---------------------------
# Step 4: Streamlit UI
# ---------------------------
st.title("🎵 Music Recommendation System")
st.write("Type a song name and get top recommendations!")

# User input
song_input = st.text_input("Enter a song name:")

if song_input:
    recommendations = get_recommendations(song_input, data, cosine_sim, top_n=10)
    
    if not recommendations.empty:
        st.subheader("Top 10 Recommendations:")
        st.dataframe(recommendations.reset_index(drop=True))
        
        # Optional: visualize genres
        plt.figure(figsize=(8,4))
        sns.countplot(data=recommendations, x='genre', order=recommendations['genre'].value_counts().index)
        plt.title("Distribution of Genres in Recommendations")
        plt.xticks(rotation=45)
        st.pyplot(plt)
# Out:
# 2025-12-28 05:26:41.682 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-12-28 05:26:41.686 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-12-28 05:26:41.689 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-28 05:26:44.054
# ...
#   command:
#
#     streamlit run C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-12-28 05:26:44.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-28 05:26:44.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-28 05:26:44.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
