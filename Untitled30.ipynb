# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %%
print("all the files have been imported successfully")
# Out:
# all the files have been imported successfully

# %%
df=pd.read_excel(r"C:\Users\User\Downloads\Sales_Orders Data file.xlsx")

# %%
df.head()
# Out:
#    OrderID    CustomerName ProductCategory ProductName  Quantity  UnitPrice  \
# 0  ORD1000  Brittany Rubio        Clothing     Message         7     300.36
# 1  ORD1001    Susan Bailey           Books  Difference         4     229.89
# 2  ORD1002  Joshua Edwards            Toys     Instead         9     264.03
# 3  ORD1003       Debra Lee     Electronics    Probably         4     120.54
# 4  ORD1004   Linda Padilla        Clothing       Truth         7     133.05
#
#    OrderDate Region SalesPerson  TotalSales
# 0 2025-05-04   East        Sara     2102.52
# 1 2025-07-14  South        John      919.56
# 2 2025-01-18   West        John     2376.27
# 3 2024-12-14   East        Amna      482.16
# 4 2024-10-14   East       David      931.35

# %%
df.shape
# Out:
# (300, 10)

# %%
df.isnull().sum()
# Out:
# OrderID            0
# CustomerName       0
# ProductCategory    0
# ProductName        1
# Quantity           0
# UnitPrice          0
# OrderDate          0
# Region             0
# SalesPerson        0
# TotalSales         0
# dtype: int64

# %%
df.describe()
# Out:
#          Quantity   UnitPrice            OrderDate   TotalSales
# count  300.000000  300.000000                  300   300.000000
# mean     5.423333  253.286633  2025-03-05 13:02:24  1380.900233
# min      1.000000   10.510000  2024-09-01 00:00:00    21.510000
# 25%      3.000000  116.187500  2024-12-13 18:00:00   440.617500
# 50%      5.000000  257.005000  2025-03-10 00:00:00  1063.165000
# 75%      8.000000  375.605000  2025-05-31 12:00:00  2119.117500
# max     10.000000  499.970000  2025-08-31 00:00:00  4923.900000
# std      2.814937  146.608432                  NaN  1143.379261

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerName', 'ProductCategory', 'ProductName', 'Quantity',
#        'UnitPrice', 'OrderDate', 'Region', 'SalesPerson', 'TotalSales'],
#       dtype='object')

# %%
df[['Quantity','UnitPrice', 'OrderDate','TotalSales']].plot()
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          300 non-null    object
#  1   CustomerName     300 non-null    object
#  2   ProductCategory  300 non-null    object
#  3   ProductName      299 non-null    object
#  4   Quantity         300 non-null    int64
#  5   UnitPrice        300 non-null    float64
#  6   OrderDate        300 non-null    datetime64[ns]
#  7   Region           300 non-null    object
#  8   SalesPerson      300 non-null    object
#  9   TotalSales       300 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 23.6+ KB

# %%
df.drop_duplicates()
# Out:
#      OrderID      CustomerName  ProductCategory ProductName  Quantity  \
# 0    ORD1000    Brittany Rubio         Clothing     Message         7
# 1    ORD1001      Susan Bailey            Books  Difference         4
# 2    ORD1002    Joshua Edwards             Toys     Instead         9
# 3    ORD1003         Debra Lee      Electronics    Probably         4
# 4    ORD1004     Linda Padilla         Clothing       Truth         7
# ..       ...               ...              ...         ...       ...
# 295  ORD1295      Amber Wilson  Home Appliances         Eat         6
# 296  ORD1296  Jacqueline David  Home Appliances       Enjoy         9
# 297  ORD1297    Kimberly Bates             Toys    Economic         8
# 298  ORD1298    Robin Martinez         Clothing     Hundred         6
# 299  ORD1299    Douglas Watson            Books     History         2
#
#      UnitPrice  OrderDate Region SalesPerson  TotalSales
# 0       300.36 2025-05-04   East        Sara     2102.52
# ...
