# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\User\OneDrive\Desktop\train.csv")

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Age'].min()
# Out:
# np.float64(0.42)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
numeric_columns=['Ticket', 'Fare','Sex', 'Age']

# %%
df2=pd.DataFrame(numeric_columns)

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.hist(figsize=(20,5),bins=60)
# Out:
# array([[<Axes: title={'center': 'PassengerId'}>,
#         <Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SibSp'}>,
#         <Axes: title={'center': 'Parch'}>],
#        [<Axes: title={'center': 'Fare'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df.scatter()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25352\775846558.py in ?()
# ----> 1 df.scatter()
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'scatter'

# %%
df.to_csv("path")

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\User\Downloads\advertising.csv")


df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
pd.set_option("display.max_rows",205)

# %%
pd.set_option("display.max_columns",10)

# %%
df.shape
# Out:
# (200, 4)

# %%
df.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
df=pd.read_csv(r"C:\Users\User\Downloads\advertising.csv",index_col="TV")

# %%
df.iloc[1]
# Out:
# Radio        39.3
# Newspaper    45.1
# Sales        10.4
# Name: 44.5, dtype: float64

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# 5      8.7   48.9       75.0    7.2
# 6     57.5   32.8       23.5   11.8
# 7    120.2   19.6       11.6   13.2
# 8      8.6    2.1        1.0    4.8
# 9    199.8    2.6       21.2   15.6
# 10    66.1    5.8       24.2   12.6
# 11   214.7   24.0        4.0   17.4
# 12    23.8   35.1       65.9    9.2
# 13    97.5    7.6        7.2   13.7
# 14   204.1   32.9       46.0   19.0
# 15   195.4   47.7       52.9   22.4
# 16    67.8   36.6      114.0   12.5
# 17   281.4   39.6       55.8   24.4
# 18    69.2   20.5       18.3   11.3
# 19   147.3   23.9       19.1   14.6
# 20   218.4   27.7       53.4   18.0
# 21   237.4    5.1       23.5   17.5
# 22    13.2   15.9       49.6    5.6
# 23   228.3   16.9       26.2   20.5
# 24    62.3   12.6       18.3    9.7
# ...

# %%
df.groupby("TV").mean()
# Out:
#        Radio  Newspaper  Sales
# TV
# 0.7    39.60       8.70   1.60
# 4.1    11.60       5.70   3.20
# 5.4    29.90       9.40   5.30
# 7.3    28.10      41.40   5.50
# 7.8    38.90      50.60   6.60
# 8.4    27.20       2.10   5.70
# 8.6     2.10       1.00   4.80
# 8.7    48.90      75.00   7.20
# 11.7   36.90      45.20   7.30
# 13.1    0.40      25.60   5.30
# 13.2   15.90      49.60   5.60
# 16.9   43.70      89.40   8.70
# 17.2   25.00      50.45   8.95
# 17.9   37.60      21.60   8.00
# 18.7   12.10      23.40   6.70
# 18.8   21.70      50.40   7.00
# 19.4   16.00      22.30   6.60
# 19.6   20.10      17.00   7.60
# 23.8   35.10      65.90   9.20
# 25.0   11.00      29.70   7.20
# 25.1   25.70      43.30   8.50
# 25.6   39.00       9.30   9.50
# 26.8   33.00      19.30   8.80
# 27.5    1.60      20.70   6.90
# 28.6    1.50      33.00   7.30
# 31.5   24.60       2.20  11.00
# 36.9   38.60      65.60  10.80
# 38.0   40.30      11.90  10.90
# 38.2    3.70      13.80   7.60
# ...

# %%
df=pd.read_csv(r"C:\Users\User\Downloads\project1_df.csv")

# %%
df.shape
# Out:
# (55000, 13)

# %%
df.head(10)
# Out:
#       CID         TID  Gender     Age Group        Purchase Date  ...  \
# 0  943146  5876328741  Female         25-45  30/08/2023 20:27:08  ...
# 1  180079  1018503182    Male         25-45  23/02/2024 09:33:46  ...
# 2  337580  3814082218   Other  60 and above  06/03/2022 09:09:50  ...
# 3  180333  1395204173   Other  60 and above  04/11/2020 04:41:57  ...
# 4  447553  8009390577    Male         18-25  31/05/2022 17:00:32  ...
# 5  200614  3994452858    Male         18-25  12/07/2021 15:10:27  ...
# 6  668787  9460023916    Male         25-45  08/10/2023 16:59:52  ...
# 7  933551  6877673032  Female         18-25  14/12/2022 20:13:45  ...
# 8  414167  2841266620    Male         18-25  29/04/2020 09:10:46  ...
# 9  889269  1342270638   Other  60 and above  18/12/2023 19:04:02  ...
#
#   Discount Amount (INR) Gross Amount   Net Amount  Purchase Method   Location
# 0                 64.30   725.304000   661.004000      Credit Card  Ahmedabad
# ...

# %%
pd.set_option("display.max_columns",14)

# %%
df.drop(columns=["Discount Name"])
# Out:
#           CID         TID  Gender     Age Group        Purchase Date  \
# 0      943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1      180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2      337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3      180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4      447553  8009390577    Male         18-25  31/05/2022 17:00:32
# ...       ...         ...     ...           ...                  ...
# 54995  295864  5407639888   Other         25-45  23/02/2020 10:42:04
# 54996  706435  1144029904   Other         18-25  12/07/2021 15:59:21
# 54997  649435  9587323189    Male         45-60  02/08/2024 09:30:44
# 54998  982183  5032564481  Female         45-60  05/08/2020 23:57:56
# 54999  126691  9172953722    Male         25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed  Discount Amount (INR)  \
# 0            Electronics              Yes                  64.30
# ...

# %%
df.columns
# Out:
# Index(['CID', 'TID', 'Gender', 'Age Group', 'Purchase Date',
#        'Product Category', 'Discount Availed', 'Discount Name',
#        'Discount Amount (INR)', 'Gross Amount', 'Net Amount',
#        'Purchase Method', 'Location'],
#       dtype='object')

# %%
df.groupby("Gender").count()
# Out:
#           CID    TID  Age Group  Purchase Date  Product Category  \
# Gender
# Female  18454  18454      18454          18454             18454
# Male    18096  18096      18096          18096             18096
# Other   18450  18450      18450          18450             18450
#
#         Discount Availed  Discount Name  Discount Amount (INR)  Gross Amount  \
# Gender
# Female             18454           9186                  18454         18454
# Male               18096           8991                  18096         18096
# Other              18450           9238                  18450         18450
#
#         Net Amount  Purchase Method  Location
# Gender
# Female       18454            18454     18454
# Male         18096            18096     18096
# Other        18450            18450     18450

# %%
df.set_index("Location")
# Out:
#               CID         TID  Gender     Age Group        Purchase Date  \
# Location
# Ahmedabad  943146  5876328741  Female         25-45  30/08/2023 20:27:08
# Bangalore  180079  1018503182    Male         25-45  23/02/2024 09:33:46
# Delhi      337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# Delhi      180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# Delhi      447553  8009390577    Male         18-25  31/05/2022 17:00:32
# ...           ...         ...     ...           ...                  ...
# Other      295864  5407639888   Other         25-45  23/02/2020 10:42:04
# Bangalore  706435  1144029904   Other         18-25  12/07/2021 15:59:21
# Mumbai     649435  9587323189    Male         45-60  02/08/2024 09:30:44
# Kolkata    982183  5032564481  Female         45-60  05/08/2020 23:57:56
# Mumbai     126691  9172953722    Male         25-45  21/07/2022 09:05:18
#
#             Product Category Discount Availed    Discount Name  \
# Location
# ...

# %%
df.iloc[1]
# Out:
# CID                                   180079
# TID                               1018503182
# Gender                                  Male
# Age Group                              25-45
# Purchase Date            23/02/2024 09:33:46
# Product Category                 Electronics
# Discount Availed                         Yes
# Discount Name                SEASONALOFFER21
# Discount Amount (INR)                 175.19
# Gross Amount                     4638.991875
# Net Amount                       4463.801875
# Purchase Method                  Credit Card
# Location                           Bangalore
# Name: 1, dtype: object

# %%
df.dtypes
# Out:
# CID                        int64
# TID                        int64
# Gender                    object
# Age Group                 object
# Purchase Date             object
# Product Category          object
# Discount Availed          object
# Discount Name             object
# Discount Amount (INR)    float64
# Gross Amount             float64
# Net Amount               float64
# Purchase Method           object
# Location                  object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55000 entries, 0 to 54999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CID                    55000 non-null  int64
#  1   TID                    55000 non-null  int64
#  2   Gender                 55000 non-null  object
#  3   Age Group              55000 non-null  object
#  4   Purchase Date          55000 non-null  object
#  5   Product Category       55000 non-null  object
#  6   Discount Availed       55000 non-null  object
#  7   Discount Name          27415 non-null  object
#  8   Discount Amount (INR)  55000 non-null  float64
#  9   Gross Amount           55000 non-null  float64
#  10  Net Amount             55000 non-null  float64
#  11  Purchase Method        55000 non-null  object
#  12  Location               55000 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 5.5+ MB

# %%
df.isna().sum()
# Out:
# CID                          0
# TID                          0
# Gender                       0
# Age Group                    0
# Purchase Date                0
# Product Category             0
# Discount Availed             0
# Discount Name            27585
# Discount Amount (INR)        0
# Gross Amount                 0
# Net Amount                   0
# Purchase Method              0
# Location                     0
# dtype: int64

# %%
df=df.drop(columns=["Discount Name"])

# %%
df
# Out:
#           CID         TID  Gender     Age Group        Purchase Date  \
# 0      943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1      180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2      337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3      180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4      447553  8009390577    Male         18-25  31/05/2022 17:00:32
# ...       ...         ...     ...           ...                  ...
# 54995  295864  5407639888   Other         25-45  23/02/2020 10:42:04
# 54996  706435  1144029904   Other         18-25  12/07/2021 15:59:21
# 54997  649435  9587323189    Male         45-60  02/08/2024 09:30:44
# 54998  982183  5032564481  Female         45-60  05/08/2020 23:57:56
# 54999  126691  9172953722    Male         25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed  Discount Amount (INR)  \
# 0            Electronics              Yes                  64.30
# ...

# %%
df.isna().sum()
# Out:
# CID                      0
# TID                      0
# Gender                   0
# Age Group                0
# Purchase Date            0
# Product Category         0
# Discount Availed         0
# Discount Amount (INR)    0
# Gross Amount             0
# Net Amount               0
# Purchase Method          0
# Location                 0
# dtype: int64

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\User\Downloads\project1_df.csv")

df
# Out:
#           CID         TID  Gender     Age Group        Purchase Date  \
# 0      943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1      180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2      337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3      180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4      447553  8009390577    Male         18-25  31/05/2022 17:00:32
# ...       ...         ...     ...           ...                  ...
# 54995  295864  5407639888   Other         25-45  23/02/2020 10:42:04
# 54996  706435  1144029904   Other         18-25  12/07/2021 15:59:21
# 54997  649435  9587323189    Male         45-60  02/08/2024 09:30:44
# 54998  982183  5032564481  Female         45-60  05/08/2020 23:57:56
# 54999  126691  9172953722    Male         25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed    Discount Name  \
# 0            Electronics              Yes        FESTIVE50
# ...

# %%
df=df.drop(columns=["Discount Name"])

# %%
df
# Out:
#           CID         TID  Gender     Age Group        Purchase Date  \
# 0      943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1      180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2      337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3      180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4      447553  8009390577    Male         18-25  31/05/2022 17:00:32
# ...       ...         ...     ...           ...                  ...
# 54995  295864  5407639888   Other         25-45  23/02/2020 10:42:04
# 54996  706435  1144029904   Other         18-25  12/07/2021 15:59:21
# 54997  649435  9587323189    Male         45-60  02/08/2024 09:30:44
# 54998  982183  5032564481  Female         45-60  05/08/2020 23:57:56
# 54999  126691  9172953722    Male         25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed  Discount Amount (INR)  \
# 0            Electronics              Yes                  64.30
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55000 entries, 0 to 54999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CID                    55000 non-null  int64
#  1   TID                    55000 non-null  int64
#  2   Gender                 55000 non-null  object
#  3   Age Group              55000 non-null  object
#  4   Purchase Date          55000 non-null  object
#  5   Product Category       55000 non-null  object
#  6   Discount Availed       55000 non-null  object
#  7   Discount Amount (INR)  55000 non-null  float64
#  8   Gross Amount           55000 non-null  float64
#  9   Net Amount             55000 non-null  float64
#  10  Purchase Method        55000 non-null  object
#  11  Location               55000 non-null  object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 5.0+ MB

# %%
df.columns
# Out:
# Index(['CID', 'TID', 'Gender', 'Age Group', 'Purchase Date',
#        'Product Category', 'Discount Availed', 'Discount Amount (INR)',
#        'Gross Amount', 'Net Amount', 'Purchase Method', 'Location'],
#       dtype='object')

# %%
df.head(7)
# Out:
#       CID         TID  Gender     Age Group        Purchase Date  \
# 0  943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1  180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2  337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3  180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4  447553  8009390577    Male         18-25  31/05/2022 17:00:32
# 5  200614  3994452858    Male         18-25  12/07/2021 15:10:27
# 6  668787  9460023916    Male         25-45  08/10/2023 16:59:52
#
#    Product Category Discount Availed  Discount Amount (INR)  Gross Amount  \
# 0       Electronics              Yes                  64.30    725.304000
# 1       Electronics              Yes                 175.19   4638.991875
# 2          Clothing              Yes                 211.54   1986.372575
# 3  Sports & Fitness               No                   0.00   5695.612650
# 4  Sports & Fitness              Yes                 439.92   2292.651500
# ...

# %%
import matplotlib.pyplot as plt

df
# Out:
#           CID         TID  Gender     Age Group        Purchase Date  \
# 0      943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1      180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2      337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3      180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4      447553  8009390577    Male         18-25  31/05/2022 17:00:32
# ...       ...         ...     ...           ...                  ...
# 54995  295864  5407639888   Other         25-45  23/02/2020 10:42:04
# 54996  706435  1144029904   Other         18-25  12/07/2021 15:59:21
# 54997  649435  9587323189    Male         45-60  02/08/2024 09:30:44
# 54998  982183  5032564481  Female         45-60  05/08/2020 23:57:56
# 54999  126691  9172953722    Male         25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed  Discount Amount (INR)  \
# 0            Electronics              Yes                  64.30
# ...

# %%
plt.bar(Gender,"Gross Amount,col="red")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plt.bar("Gender","Gross Amount",col="red")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:2990, in bar(x, height, width, bottom, align, data, **kwargs)
#    2979 @_copy_docstring_and_deprecators(Axes.bar)
#    2980 def bar(
#    2981     x: float | ArrayLike,
#    (...)   2988     **kwargs,
#    2989 ) -> BarContainer:
# -> 2990     return gca().bar(
#    2991         x,
#    2992         height,
#    2993         width=width,
#    2994         bottom=bottom,
#    2995         align=align,
#    2996         **({"data": data} if data is not None else {}),
#    2997         **kwargs,
#    2998     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
# ...
