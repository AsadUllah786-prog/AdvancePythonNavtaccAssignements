# %%
city = input("Enter a city you want to visit: ")

city = city.strip().title()  


prompt = f"Suggest 3 tourist attractions in {city}."


print("Generated Prompt:", prompt)
# Out:
# Enter a city you want to visit:  Lahore
# Generated Prompt: Suggest 3 tourist attractions in Lahore.

# %%
city=input("enter a city you want to visit")

city=city.strip().title()
print(city)

prompt=f"suggest 3 best tourist attractions in {city}"

print("generated prompt",prompt)
# Out:
# enter a city you want to visit     tokyo
# Tokyo
# generated prompt suggest 3 best tourist attractions in Tokyo

# %%
cities=[]

city=input("enter a city or 1 to exit")
while city!="1":
    cities=cities +[city]
    city=input("enter another city or 1 to exit")



print(cities)
# Out:
# enter a city or 1 to exit london
# enter another city or 1 to exit germany
# enter another city or 1 to exit 1
# (([], ['london']), ['germany'])

# %%
cities=[]

city=input("enter a city or 1 to exit")
count=0
while city!="1":
    cities=cities +[None]
    cities[count]=city
    count+=1
    city=input("enter another city or 1 to exit")


print(cities)
# Out:
# enter a city or 1 to exit london
# enter another city or 1 to exit germany
# enter another city or 1 to exit 1
# ['london', 'germany']

# %%
cities=[]

city=input("enter a city or 1 to exit")
while city!="1":
    cities=[*cities ,city]
    city=input("enter another city or 1 to exit")

print(cities)
# Out:
# enter a city or 1 to exit london
# enter another city or 1 to exit germany
# enter another city or 1 to exit tokyo
# enter another city or 1 to exit 1
# ['london', 'germany', 'tokyo']

# %% [raw]
# tahajud wakeup bot

# %%
from datetime import datetime

currTime=datetime.now().time()
print(currTime)

currTime=str(currTime)
print(type(currTime))



if currTime=="03:30:40":
    prompt=f"its time to wakeup for tahajjud"
elif currTime=="03:45:40":
    prompt=f"just 10 minutes remaining in tahajudd time ending"
else:
    prompt=f"wake up now its fajar time"

print("generated prompt:", prompt)
# Out:
# 05:26:24.516721
# <class 'str'>
# generated prompt: wake up now its fajar time

# %% [raw]
# student buddy app

# %%
studentInput=input("enter your query with topic")

prompt=f"base on your input {studentInput} here are the top 3 long questions which havehigher chances to appear in exams"

print("generated prompt",prompt)
