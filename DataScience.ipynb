# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Practical Task — Employee Salary Analysis

# %%
salaries_in_thousands=[25, 30, 30, 35, 40, 45, 50, 30, 28, 32, 34, 36, 38, 120, 42]

# %%
# What is population?
population=500
# What is sample?
sample=15

# %% [markdown]
# # Measures Of Central Tendency

# %%
mean_salary=np.mean(salaries_in_thousands)
mean_salary
# Out:
# np.float64(41.0)

# %%
median_salary=np.median(salaries_in_thousands)
median_salary
# Out:
# np.float64(35.0)

# %%
from scipy import stats
mode_salary=stats.mode(salaries_in_thousands)

# %%
mode_salary[0]
# Out:
# np.int64(30)

# %%
plt.boxplot(salaries_in_thousands)
plt.show()

# %%
plt.hist(salaries_in_thousands,bins=5)
plt.show()

# %% [markdown]
# # Measures Of Variability

# %%
range_salary=max(salaries_in_thousands)-min(salaries_in_thousands)

# %%
range_salary
# Out:
# 95

# %%
Mad_Salary=np.sum(np.abs(salaries_in_thousands-np.mean(salaries_in_thousands)))/len(salaries_in_thousands)

# %%
Mad_Salary
# Out:
# np.float64(12.4)

# %%
mean_salary=np.mean(salaries_in_thousands)

# %%
mean_salary
# Out:
# np.float64(41.0)

# %%
Mean =41.0
Median =35.0
Mode =30.0
Range =95
MAD =12.4

Conclusion= """
The dataset contains an outlier (120), which increases the mean and the range.
Because of this outlier, the distribution is right-skewed (positively skewed),
where Mean > Median > Mode.

Median is a better measure of central tendency for this dataset
because it is not affected by extreme values.

High range and MAD indicate that the salaries are widely spread.

For missing values, median is preferred over mean.
For the outlier, we may remove it, cap it, or investigate it depending on business context.
"""

# %%
import numpy as np

np.random.seed(42)

population_marks=np.random.randint(40,100,200)
sample_marks=np.random.randint(40,100,25)

# %%
sample_marks
# Out:
# array([46, 98, 90, 61, 67, 41, 81, 84, 96, 92, 45, 67, 67, 83, 83, 59, 69,
#        50, 97, 94, 67, 64, 78, 72, 40], dtype=int32)

# %%
highestMarks=max(sample_marks)
lowestMarks=min(sample_marks)

# %%
(highestMarks,lowestMarks)
# Out:
# (np.int32(98), np.int32(40))

# %%
range_marks=highestMarks-lowestMarks

# %%
range_marks
# Out:
# np.int32(58)

# %%
mean_marks=np.mean(sample_marks)

# %%
mean_marks
# Out:
# np.float64(71.64)

# %%
median_marks=np.median(sample_marks)

# %%
median_marks
# Out:
# np.float64(69.0)

# %%
np.sum(np.abs(sample_marks-mean_marks))/len(sample_marks)
# Out:
# np.float64(15.0656)

# %%
mode_marks=stats.mode(sample_marks)

# %%
mode_marks
# Out:
# ModeResult(mode=np.int32(67), count=np.int64(4))

# %%
print(type(sample_marks))

sample_with_outlier=list(sample_marks)

sample_with_outlier.append(0)

sample_with_outlier
# Out:
# <class 'numpy.ndarray'>
# [np.int32(46),
#  np.int32(98),
#  np.int32(90),
#  np.int32(61),
#  np.int32(67),
#  np.int32(41),
#  np.int32(81),
#  np.int32(84),
#  np.int32(96),
#  np.int32(92),
#  np.int32(45),
#  np.int32(67),
#  np.int32(67),
#  np.int32(83),
#  np.int32(83),
#  np.int32(59),
#  np.int32(69),
#  np.int32(50),
#  np.int32(97),
#  np.int32(94),
#  np.int32(67),
#  np.int32(64),
#  np.int32(78),
#  np.int32(72),
#  np.int32(40),
#  0]

# %%
np.mean(sample_with_outlier)
# Out:
# np.float64(68.88461538461539)

# %%
np.median(sample_with_outlier)
# Out:
# np.float64(68.0)

# %%
import numpy as np

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\User\Downloads\Messy_Employee_dataset.csv")

# %%
data.head()
# Out:
#   Employee_ID First_Name Last_Name   Age   Department_Region    Status  \
# 0     EMP1000        Bob     Davis  25.0   DevOps-California    Active
# 1     EMP1001        Bob     Brown   NaN       Finance-Texas    Active
# 2     EMP1002      Alice     Jones   NaN        Admin-Nevada   Pending
# 3     EMP1003        Eva     Davis  25.0        Admin-Nevada  Inactive
# 4     EMP1004      Frank  Williams  25.0  Cloud Tech-Florida    Active
#
#     Join_Date     Salary                       Email       Phone  \
# 0    4/2/2021   59767.65       bob.davis@example.com -1651623197
# 1   7/10/2020   65304.66       bob.brown@example.com -1898471390
# 2   12/7/2023   88145.90     alice.jones@example.com -5596363211
# 3  11/27/2021   69450.99       eva.davis@example.com -3476490784
# 4    1/5/2022  109324.61  frank.williams@example.com -1586734256
#
#   Performance_Score  Remote_Work
# 0           Average         True
# 1         Excellent         True
# 2              Good         True
# ...

# %%
data.isnull().sum()
# Out:
# Employee_ID            0
# First_Name             0
# Last_Name              0
# Age                  211
# Department_Region      0
# Status                 0
# Join_Date              0
# Salary                24
# Email                  0
# Phone                  0
# Performance_Score      0
# Remote_Work            0
# dtype: int64

# %%
median=data["Salary"].median()

# %%
median
# Out:
# np.float64(85547.87)

# %%
data["Salary"]=data["Salary"].fillna(median)

# %%
data["Salary"].isnull().sum()
# Out:
# np.int64(0)

# %%
data["Salary"].describe()

data["Salary"].median()
# Out:
# np.float64(85547.87)

# %%
median=85547
mean=data["Salary"].mean()

# %%
print(median,mean)
# Out:
# 85547 85164.29906862746

# %%
if median>mean:
    print("left skewed")
else:
    print("right skewws")
# Out:
# left skewed

# %%
cv=(data["Salary"].std())/data["Salary"].mean()

# %%
print((cv))
# Out:
# 0.23059410991610024

# %%
"data is stable"
# Out:
# 'data is stable'
