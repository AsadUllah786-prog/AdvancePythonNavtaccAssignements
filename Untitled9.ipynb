# %%
# Out:
# Enter details for customer 1:
# Name:  asad
# Age:  19
# Email:  au
# Enter details for customer 2:
# Name:  saqib
# Age:  20
# Email:  saqib@gmail.com
# Enter details for customer 3:
# Name:  usman
# Age:  21
# Email:  usman@gmail.com
# Customer List:
# asad (19 years old) - au
# saqib (20 years old) - saqib@gmail.com
# usman (21 years old) - usman@gmail.com

# %%
shoppingList=[]

for i in range(3):
    print(f"enter the details of shoppinglist  {i+1} :")
    name=input("name")
    price=int(input("price"))
    forsale=input("for sale or not")

    shoppinglist={"name":name, "price":price, "forsale":forsale}

    shoppingList.append(shoppinglist);

print("\nCustomer List:")
for shoppingList in shopping:
    print(f"{shopping['name']} ({shopping['price']} years old) - {shopping['forsale']}")
