# %%
# !pip install openai
# Out:
# ...
#    ---------------------------------------- 0.0/786.2 kB ? eta -:--:--
#    ------------- -------------------------- 262.1/786.2 kB ? eta -:--:--
#    ---------------------------------------- 786.2/786.2 kB 2.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 3.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.8/2.0 MB 2.8 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/2.0 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 2.6 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/8 [typing-inspection]
#    ----- ---------------------------------- 1/8 [tqdm]
#    ----- ---------------------------------- 1/8 [tqdm]
#    ----- ---------------------------------- 1/8 [tqdm]
#    ----- ---------------------------------- 1/8 [tqdm]
#    ----- ---------------------------------- 1/8 [tqdm]
# ...

# %%
import openai
